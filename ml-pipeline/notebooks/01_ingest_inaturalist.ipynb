# %% [markdown]
# # 01 — Ingest iNaturalist Roadkill Data
#
# Run this notebook to query iNaturalist for India roadkill observations,
# cross-check GBIF counts, and save clean GeoJSON for downstream use.
#
# ## Usage
# ```python
# from ml_pipeline.src.ingest import run_ingestion
# result = run_ingestion()
# print(result["summary"])
# ```
